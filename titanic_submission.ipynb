# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('C:/Users/HP/Documents/csv file/train.csv')
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1.drop(['PassengerId','Ticket','Cabin','Embarked','Name','SibSp','Parch'], axis=1, inplace=True)
data1
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
data1.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
data1.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
data1['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data1['Age'].fillna(data1['Age'].mean(),inplace=True)
data1['Fare'].fillna(data1['Fare'].mean(),inplace=True)
data1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %%
sns.catplot(x='Sex',hue='Survived',kind='count',data=data1)

# %%
sns.violinplot(x='Sex',y='Age',hue='Survived',data=data1,split=True)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sex_dummies=pd.get_dummies(data1['Sex'],drop_first=True)

# %%
data1=pd.concat([data1,sex_dummies],axis=1)
data1
# Out:
#      Survived  Pclass     Sex        Age     Fare  male
# 0           0       3    male  22.000000   7.2500     1
# 1           1       1  female  38.000000  71.2833     0
# 2           1       3  female  26.000000   7.9250     0
# 3           1       1  female  35.000000  53.1000     0
# 4           0       3    male  35.000000   8.0500     1
# ..        ...     ...     ...        ...      ...   ...
# 886         0       2    male  27.000000  13.0000     1
# 887         1       1  female  19.000000  30.0000     0
# 888         0       3  female  29.699118  23.4500     0
# 889         1       1    male  26.000000  30.0000     1
# 890         0       3    male  32.000000   7.7500     1
#
# [891 rows x 6 columns]

# %%
data1.drop(['Sex'],axis=1,inplace=True)
data1.head()
# Out:
#    Survived  Pclass   Age     Fare  male
# 0         0       3  22.0   7.2500     1
# 1         1       1  38.0  71.2833     0
# 2         1       3  26.0   7.9250     0
# 3         1       1  35.0  53.1000     0
# 4         0       3  35.0   8.0500     1

# %%
from sklearn.preprocessing import StandardScaler
sts=StandardScaler()

# %%
feature_Scale=['Age','Fare']
data1[feature_Scale]=sts.fit_transform(data1[feature_Scale])

# %%
 data1.head()
# Out:
#    Survived  Pclass       Age      Fare  male
# 0         0       3 -0.592481 -0.502445     1
# 1         1       1  0.638789  0.786845     0
# 2         1       3 -0.284663 -0.488854     0
# 3         1       1  0.407926  0.420730     0
# 4         0       3  0.407926 -0.486337     1

# %%
x=data1.drop(['Survived'],axis=1) # here Pclass	Age	Fare	male are feature variable so i have to drop a Survived variable !!
y=data1["Survived"]  #target variable

# %%
# here we import a library to search a best fit model !!
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
model_param={
    'DecisionTreeClassifier':{
        'model':DecisionTreeClassifier(),
        'param':{
            'criterion':['gini','entropy']
             }
    },

        'KNeighborsClassifier':{
        'model':KNeighborsClassifier(),
        'param':{
            'n_neighbors':[5,10,15,20,25]
        }
    },
        'SVC':{
            'model':SVC(),
            'param':{
                'kernel':['rbf','linear','sigmoid'],
                'C':[0.1,1,10,100]
            }
        }
    
    
}

# %%
scores=[]
for model_name ,mp in model_param.items():
    model_selection=GridSearchCV(estimator=mp['model'],param_grid=mp['param'],cv=5,return_train_score=False)
    model_selection.fit(x,y)
    scores.append({
    'model': model_name,
    'best_score':model_selection.best_score_,
    'best_params':model_selection.best_params_,
    })

# %%
data1_model_score=pd.DataFrame(scores,columns=['model','best_score','best_params'])
data1_model_score
# Out:
#                     model  best_score                  best_params
# 0  DecisionTreeClassifier    0.773348        {'criterion': 'gini'}
# 1    KNeighborsClassifier    0.802492           {'n_neighbors': 5}
# 2                     SVC    0.811481  {'C': 100, 'kernel': 'rbf'}

# %%
model_svc=SVC(C=100,kernel='rbf')
model_svc.fit(x,y)
# Out:
# SVC(C=100)

# %%
data2=pd.read_csv('C:/Users/HP/Documents/csv file/test.csv')
data2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data2.drop(['PassengerId','Ticket','Cabin','Embarked','Name','SibSp','Parch'], axis=1, inplace=True)
data2.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  34.5   7.8292
# 1       3  female  47.0   7.0000
# 2       2    male  62.0   9.6875
# 3       3    male  27.0   8.6625
# 4       3  female  22.0  12.2875

# %%
data2.isnull().sum()
# Out:
# Pclass     0
# Sex        0
# Age       86
# Fare       1
# dtype: int64

# %%
data2['Age'].fillna(data1['Age'].mean(),inplace=True)
data2['Fare'].fillna(data1['Fare'].mean(),inplace=True)
data1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Age         0
# Fare        0
# male        0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
data2.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  34.5   7.8292
# 1       3  female  47.0   7.0000
# 2       2    male  62.0   9.6875
# 3       3    male  27.0   8.6625
# 4       3  female  22.0  12.2875

# %%
sex_dummies=pd.get_dummies(data2['Sex'],drop_first=True)

# %%
data2=pd.concat([data2,sex_dummies],axis=1)
data2.head()
# Out:
#    Pclass     Sex   Age     Fare  male
# 0       3    male  34.5   7.8292     1
# 1       3  female  47.0   7.0000     0
# 2       2    male  62.0   9.6875     1
# 3       3    male  27.0   8.6625     1
# 4       3  female  22.0  12.2875     0

# %%
data2.drop(['Sex'],axis=1,inplace=True)

# %%
data2.head()
# Out:
#    Pclass       Age      Fare  male
# 0       3  0.594801 -0.496637     1
# 1       3  1.305896 -0.511497     0
# 2       2  2.159209 -0.463335     1
# 3       3  0.168145 -0.481704     1
# 4       3 -0.116293 -0.416740     0

# %%
data2[feature_Scale]=sts.fit_transform(data2[feature_Scale])

# %%
data2.head()
# Out:
#    Pclass       Age      Fare  male
# 0       3  0.594801 -0.496637     1
# 1       3  1.305896 -0.511497     0
# 2       2  2.159209 -0.463335     1
# 3       3  0.168145 -0.481704     1
# 4       3 -0.116293 -0.416740     0

# %%
y_predict=model_svc.predict(data2)

# %%
submission=pd.DataFrame({
    'Survived':y_predict
})

# %%
submission.to_csv('titanic_submission.csv',index=False)
